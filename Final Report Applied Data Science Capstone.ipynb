# %% [markdown]
# # Final Report | Capstone Project – The Battle of Neighborhoods Finding a Better Place in Porto

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# This Project has the main aim of this project is to help people who just arrived at the city of Porto (Portugal) to decide which is the most appropriate parish for them.
#
# Porto is included in the top 100 and the top 40, at world and European level, respectively, as a top city to live in, according to the Quality of Life Index 2019 (1). Therefore, the city has experienced a strong migration movement for the past few years. This project will help newcomers decide among the nine main parishes of Porto (2), which is the most appropriate for them based on ease of access to shops, theaters, schools, health care services, etc.
#
# Thus, the project will determine which of the nine main parishes of Porto is better suited for each person. With this in mind, we will perform a cluster analysis to group the parishes of Porto according to the characteristics of their venues (e.g., shop, schools, supermarkets), which will help newcomers to decide which is the best type of parish for them, based on the most frequent type of venues in each parish.

# %% [markdown]
# ### 1.1 Main Problem

# %% [markdown]
# The main aim of this project is to help people moving to Porto (Portugal) to select between the nine main parishes which is better suited for them, based on the most frequent venues (e.g. schools, cafes, restaurants, housing) in each parish.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# ### 2.1 Portuguese Post Office Zip Code Database

# %% [markdown]
# To provide a solution to our main problem we will use a database provided by the Portuguese Postal Services (which can be downloaded through the link bellow) to get the information regarding the zip codes of each parish of Porto. This data base contains the all the zip codes of Portugal. The file is quite large. Therefore, we have filtered the zip codes of Porto's parish in excel and uploaded a CSV file that solely contains the zip codes of Porto's parishes.
#
# Hyperlink: https://www.ctt.pt/feapl_2/app/restricted/postalCodeSearch/postalCodeDownloadFiles.jspx

# %% [markdown]
# ### 2.2 Foursquare API Data

# %% [markdown]
# In order to gather  information we will use "Foursquare" locational information about the venues present in each parish. Foursquare is a location data provider that allows us to retrieve information about venues within an area of interest. The API allows us to retrieve information about venue names, locations, menus and even photos. The foursquare location platform will be used as the sole data source.
#
# After we gather the information regarding the geolocation of the nine parishes of Porto into a Dataframe, we will use the Foursquare API to gather information about venues in each parish. For each parish, we will set the radius to 700 meters.
#
# We will use this API to gather information of venues within a specified distance of the longitude and latitude of the zip code. We will gather the following information for each Parish:
#
# 1. Parish
# 2. Parish Latitude
# 3. Parish Longitude
# 4. Venue
# 5. Name of the venue e.g. the name of a store or restaurant
# 6. Venue Latitude
# 7. Venue Longitude
# 8. Venue Category

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# To solve our main problem we will use the several of Python's libraries to store and clean data, the foursquare API to gather data about the existing venues in each parish of Porto, and the k-means clustering algorithm to cluster and segment the nine parishes of porto into cluster, based on the similarities of the existing venues in each parish

# %% [markdown]
# ### 3.1 Libraries used throughout the Project

# %% [markdown]
# Folium: This library will be used to visualize the clusters of parishes and to create an interactive leaflet map.
#
# Pandas: To create and manipulate dataframes.
#
# Numpy: To help to sort the venues in each parish
#
# JSON: To handle JSON files.
#
# Matplotlib: To plot graphs.
#
# Scikit Learn: To import and develop a clustering algorithm based on k-means clustering.
#
# Geocoder: To retrieve Location Data.

# %% [markdown]
# ### 3.2 Foursquare API

# %% [markdown]
# We will would the Four-square API to gahther data regading the venues of Porto's parishes.
# We will use Foursquare API features credentials of near-by places to mine the parishes. Due to http request limitations the number of places per parish parameter would reasonably be set to 100 and the radius parameter would be set to 700.

# %% [markdown]
# ### 3.3 Clustering Approach

# %% [markdown]
# To compare the nine main parishes of Porto, we will explore the parishes, segment them, and group them into clusters. To achieve this, we will cluster data with the k-means clustering algorithm.

# %% [markdown]
# ## 4. Results

# %% [markdown]
# The result of our cluster analysis suggested that the parishes of Porto can be segmented in four clusters as it can be seen in figure 1

# %% [markdown]
# ##### Figure 1

# %%
from IPython.display import Image
Image(filename='Cluster_Porto.JPG')

# %% [markdown]
# Cluster 1 is comprised by the parish of Paranhos_2 and Camapanhã_2. These most frequent venues in this cluster are bakeries, hoteis, bus Station, supermarkets.
#
# The second cluster solely was composed by Paranhos_1, which is a parish mainly populated by college cafeterias, cafés and portuguese restaurants.
#
# In its turn the cluster number 3 was comprised by Bonfim_1, Bonfim_2, Cedofeita_1, Aldoar_1, Aldoar_2. Most of Porto's parishes were aggrgated in this cluster, which suggests that most of Porto's parishes are very similar when it comes to venues. The most frequent venues in this neighborhoods are Portuguese Restaurant, Cafés, Bars, Supermarkets, suchi restaurants and hostels).
#
# At last, the fourth cluster was composed by Campanhã_1, which is mainly populated by gardens, parks, and cafes.

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# In this project, we used the k-means cluster algorithm to group Porto's parishes into 4 different clusters.
#
# Most parishes were grouped in cluster number 3 (Bonfim_1, Bonfim_2, Cedofeita_1, Aldoar_1, Aldoar_2), which means that most parishes of Porto are very similar when it comes to its venues. The most frequent venues in this neighborhoods are Portuguese Restaurant, Cafés, Bars, Supermarkets, suchi restaurants and hostels. The parishes segmented in this cluster are located in the center of Porto's Metropolitan Area, which is a more Touristic area. Therefore, it is not surprising that this parishes are mainly populated by Portuguese Restaurant, Cafés, Bars, Supermarkets, suchi restaurants and hostels. This parishes seem to be ideal for a person who is looking for an active social life and gourmet interests, giventhe elevated frequency of restaurants and cafes located in this region.
#
# Our algorithm also revealed a cluster which encapsulated two parishes Paranhos_2 and Camapanhã_2. These Parishes are geographically very close, which may explain the similarities between this two neighborhoods. These most frequent venues in this cluster are bakeries, hoteis, bus Station, supermarkets. One of the biggest railway stations of Porto is located in this area (Campanhã_2). Given that this parishes also exhibits an elevated frequency of bus stations, the parishes located in this neighborough seem to be ideal for a person who value good public transportation infrastructures.
#
# At last, our algorithm found two clusters composed by one single parish. This suggests that this two parishes are quit unique, in comparison with other parishes, when it comes to its venues.
#
# The second cluster was composed by Paranhos_1, which is a parish mainly populated by college cafeterias, cafés and portuguese restaurants. Most faculties of Porto's University are located in this parish (which may explain the elevated frequency of college cafeterias). Thus, this parish seems to be ideal for collage students.
#
# The fourth cluster was composed by Campanhã_1, which is mainly populated by gardens, parks, and cafes. The main difference between this parish and the other eight parishes is the elevated number os gardens and parks (none of the other eight parishes present any outdoor venue in their top three of there most frequent venues). Thus, it seems that this parish is ideal for people looking for a more outdoorsy lifestyle.
#
# Even though it seems that the profile of venues is quite similar in most of Porto's parishes (five out of nine parishes were aggregated in cluster 3), if we take a look at the map displayed in figue 1, it is possible to see that most of this parishes are located at the center of Porto's metropolitan area. As we step further away from the center of the Metropolitan Area, in the direction of the suburbs, the profile of the parishes seems to change. Therefore, it is possible to suggest that the Parishes of located in the center of Porto's Metropolitan area and the parishes located in the suburbs present quite different profiles when it comes to its venues. The parishes located in the center of the Metropolitan area present quite a homogenous venues profile, while the profile of the parishes located in the suburbs is quite heterogenous.

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# Porto's parishes seem to cluster into 4 different clusters.
#
# Althought it seems that most of Porto's parishes are quite similar when it comes to the profile of its venues (five out of nine parishes were aggregated in cluster 3) there seems to be a difference in the profile of the parishes located in the center of the Metropolitan area and the parishes located in the suburbs.The Parishes of located in the center of Porto's Metropolitan area present a more tourist profile when it comes to its venues (this parishes present an elevated frequency of (cafes, restaurants, and hostels), while the parishes located in the suburbs present (which present a more heterogenous profile), seems to have more venues that can be handy for a working person or a student. Therefore, if one is looking for an active social life and has culinary and cultural interest, this person should consider living closer to the Center of Porto's Metropolitan area. On the contrary college students or peson who need strong public transportation infrastrucutres, should consider living in the suburbs of Porto's Metropolitan area.
#
# In the future, it will be interesting to see how the housing prices fluctuate from parish to parish. Such a study could bring some complementary information that could help people decide which of Porto's parishes is most suited for them.

# %% [markdown]
# ## 7. Blogpost Link

# %% [markdown]
# https://www.linkedin.com/pulse/final-report-capstone-project-battle-neighborhoods-finding-monteiro/?published=t

# %% [markdown]
# ## 8. References

# %% [markdown]
# 1. Porto. https://www.porto.pt/en/news/porto-is-a-top-city-to-live-in-says-the-quality-of-life-index-2019-by-numbeo. Retrieved 9 February 2021.
# 2. Eurodicas. https://www.eurodicas.com.br/melhores-bairros-do-porto/. Retrieved 9 February 2021.
